# %%
# Read environment variables

import os
from dotenv import load_dotenv

load_dotenv(override=True)

openai_url      = os.environ['AZURE_OPENAI_URL']
openai_key      = os.environ['AZURE_OPENAI_KEY']
embeddings_dep  = os.environ['AZURE_OPENAI_EMBEDDINGS_DEP']
completions_dep = os.environ['AZURE_OPENAI_COMPLETIONS_DEP']

print("openai_url:      {}".format(openai_url))
print("openai_key:      {}".format(openai_key[0:3]))
print("embeddings_dep:  {}".format(embeddings_dep))
print("completions_dep: {}".format(completions_dep))

# See https://code.visualstudio.com/docs/datascience/jupyter-notebooks
# To select an environment, use the Python: Select Interpreter command from the Command Palette (⇧⌘P).
# Out:
# openai_url:      https://gbbcjcaigopenai3.openai.azure.com/
# openai_key:      d1b
# embeddings_dep:  embeddings
# completions_dep: gpt4

# %%
# List the pip installed current libraries in this venv.

# !pip list
# Out:
# Package                   Version
# ------------------------- ---------------
# aiofiles                  23.2.1
# aiohttp                   3.9.3
# aiosignal                 1.3.1
# annotated-types           0.6.0
# anyio                     4.3.0
# appnope                   0.1.4
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asgiref                   3.8.1
# asttokens                 2.4.1
# async-lru                 2.0.4
# attrs                     23.2.0
# Babel                     2.14.0
# beautifulsoup4            4.12.3
# bleach                    6.1.0
# build                     1.2.1
# certifi                   2024.2.2
# cffi                      1.16.0
# chardet                   5.2.0
# charset-normalizer        3.3.2
# click                     8.1.7
# comm                      0.2.1
# contourpy                 1.2.0
# cycler                    0.12.1
# dataclasses-json          0.6.4
# debugpy                   1.8.1
# decorator                 5.1.1
# defusedxml                0.7.1
# distro                    1.9.0
# dnspython                 2.6.1
# docopt                    0.6.2
# et-xmlfile                1.1.0
# executing                 2.0.1
# fastjsonschema            2.19.1
# fonttools                 4.49.0
# fqdn                      1.5.1
# frozenlist                1.4.1
# h11                       0.14.0
# httpcore                  1.0.4
# httpx                     0.27.0
# idna                      3.6
# ipykernel                 6.29.2
# ipython                   8.22.1
# isodate                   0.6.1
# isoduration               20.11.0
# jedi                      0.19.1
# Jinja2                    3.1.3
# json5                     0.9.17
# jsonpatch                 1.33
# jsonpointer               2.4
# jsonschema                4.21.1
# jsonschema-path           0.3.2
# jsonschema-spec           0.2.4
# jsonschema-specifications 2023.7.1
# jupyter_client            8.6.0
# jupyter_core              5.7.1
# jupyter-events            0.9.0
# jupyter-lsp               2.2.2
# jupyter_server            2.12.5
# jupyter_server_terminals  0.5.2
# jupyterlab                4.1.2
# jupyterlab_pygments       0.3.0
# jupyterlab_server         2.25.3
# kiwisolver                1.4.5
# langchain                 0.1.9
# langchain-community       0.0.24
# langchain-core            0.1.26
# langsmith                 0.1.7
# lazy-object-proxy         1.10.0
# MarkupSafe                2.1.5
# marshmallow               3.20.2
# matplotlib                3.8.3
# matplotlib-inline         0.1.6
# mistune                   3.0.2
# more-itertools            10.2.0
# motor                     3.4.0
# multidict                 6.0.5
# mypy-extensions           1.0.0
# nbclient                  0.9.0
# nbconvert                 7.16.1
# nbformat                  5.9.2
# nest-asyncio              1.6.0
# notebook                  7.1.0
# notebook_shim             0.2.4
# numpy                     1.26.4
# openai                    1.12.0
# openapi-core              0.18.2
# openapi-schema-validator  0.6.2
# openapi-spec-validator    0.7.1
# openpyxl                  3.1.2
# orjson                    3.9.15
# overrides                 7.7.0
# packaging                 23.2
# pandas                    2.2.1
# pandocfilters             1.5.1
# parse                     1.20.1
# parso                     0.8.3
# pathable                  0.4.3
# pexpect                   4.9.0
# pillow                    10.2.0
# pip                       24.0
# pip-tools                 7.4.1
# platformdirs              4.2.0
# prance                    23.6.21.0
# prometheus_client         0.20.0
# prompt-toolkit            3.0.43
# psutil                    5.9.8
# ptyprocess                0.7.0
# pure-eval                 0.2.2
# pycparser                 2.21
# pydantic                  2.6.2
# pydantic_core             2.16.3
# Pygments                  2.17.2
# pymongo                   4.6.2
# pyparsing                 3.1.1
# pyproject_hooks           1.1.0
# python-dateutil           2.8.2
# python-dotenv             1.0.1
# python-json-logger        2.0.7
# pytz                      2024.1
# PyYAML                    6.0.1
# pyzmq                     25.1.2
# rdflib                    7.0.0
# referencing               0.30.2
# regex                     2023.12.25
# requests                  2.31.0
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rpds-py                   0.18.0
# ruamel.yaml               0.18.6
# ruamel.yaml.clib          0.2.8
# semantic-kernel           0.9.1b1
# Send2Trash                1.8.2
# setuptools                70.0.0
# six                       1.16.0
# sniffio                   1.3.0
# soupsieve                 2.5
# SQLAlchemy                2.0.27
# stack-data                0.6.3
# tenacity                  8.2.3
# terminado                 0.18.0
# tiktoken                  0.6.0
# tinycss2                  1.2.1
# tornado                   6.4
# tqdm                      4.66.2
# traitlets                 5.14.1
# types-python-dateutil     2.8.19.20240106
# typing_extensions         4.9.0
# typing-inspect            0.9.0
# tzdata                    2024.1
# uri-template              1.3.0
# urllib3                   2.2.1
# wcwidth                   0.2.13
# webcolors                 1.13
# webencodings              0.5.1
# websocket-client          1.7.0
# Werkzeug                  3.0.3
# wheel                     0.43.0
# xmlformatter              0.2.6
# yarl                      1.9.4

# %%
from pysrc.util.fs import FS

lines = FS.read_lines('requirements.in')
for idx, line in enumerate(lines):
    print("line: {} {}".format(idx, line.strip()))
# Out:
# line: 0 # This file lists the Python libraries used in the virtual enviroment.
# line: 1 # See the venv.ps1 and venv.sh scripts in this directory.
# line: 2 # Chris Joakim
# line: 3
# line: 4 Jinja2
# line: 5 arrow
# line: 6 certifi
# line: 7 dnspython
# line: 8 docopt
# line: 9 httpx
# line: 10 notebook
# line: 11 langchain
# line: 12 langchain_community
# line: 13 matplotlib
# line: 14 numpy
# line: 15 openai
# line: 16 openpyxl
# line: 17 pandas
# line: 18 pymongo
# line: 19 python-dotenv
# line: 20 rdflib
# line: 21 tiktoken>=0.4.0
# line: 22 xmlformatter
